# %%
import sys
from pathlib import Path
print(sys.executable)
print(Path.cwd())
# Out:
# c:\Users\Naderah\Downloads\Advanced Prog for DA Hamzeh\apda-ab-test-21027897\.venv\Scripts\python.exe
# c:\Users\Naderah\Downloads\Advanced Prog for DA Hamzeh\apda-ab-test-21027897\notebooks

# %%
import numpy as np
import pandas as pd

# %%
values = np.array([10, 20, 30])
pd.Series(values).describe()
# Out:
# count     3.0
# mean     20.0
# std      10.0
# min      10.0
# 25%      15.0
# 50%      20.0
# 75%      25.0
# max      30.0
# dtype: float64
